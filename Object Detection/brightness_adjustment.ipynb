# %% [markdown]
# ## 1. Thư viện cần thiết

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2
import random

# %%
# Đường lnk lấy dataset
axial_train_dataset = '/kaggle/input/brain-tumor-by-plane-object-detection/axial_t1wce_2_class/train/'
coronal_train_dataset = '/kaggle/input/brain-tumor-by-plane-object-detection/coronal_t1wce_2_class/train/'
sagittal_train_dataset = '/kaggle/input/brain-tumor-by-plane-object-detection/sagittal_t1wce_2_class/train/'
axial_test_dataset = '/kaggle/input/brain-tumor-by-plane-object-detection/axial_t1wce_2_class/test/'
coronal_test_dataset = '/kaggle/input/brain-tumor-by-plane-object-detection/coronal_t1wce_2_class/test/'
sagittal_test_dataset = '/kaggle/input/brain-tumor-by-plane-object-detection/sagittal_t1wce_2_class/test/'

# %% [markdown]
# ## 3.3. Làm sáng ảnh

# %%
def adaptive_thresh_images(image_list):
    adaptive_thresh_images = []
    
    for image in image_list:
        # Tăng cường độ sáng
        beta = 50  # Giá trị cần thêm vào (có thể điều chỉnh)
        bright_image = cv2.convertScaleAbs(image, beta=beta)
        
        adaptive_thresh_images.append(bright_image)
    
    return adaptive_thresh_images

# %%
axial_image_train_thresh = adaptive_thresh_images(axial_image_train_sharpened)
coronal_image_train_thresh = adaptive_thresh_images(coronal_image_train_sharpened)
sagittal_image_train_thresh = adaptive_thresh_images(sagittal_image_train_sharpened)

# %%
plot_images_with_bboxes(axial_image_train_thresh, axial_labels_train,  "/kaggle/working/brain_tumor_object_detection/axial/train/labels", "Train Axial Brightness Adjustment")

# %%
plot_images_with_bboxes(coronal_image_train_thresh, coronal_labels_train,  "/kaggle/working/brain_tumor_object_detection/coronal/train/labels", "Train Coronal Brightness Adjustment")

# %%
plot_images_with_bboxes(sagittal_image_train_thresh, sagittal_labels_train,  "/kaggle/working/brain_tumor_object_detection/sagittal/train/labels", "Train Sagittal Brightness Adjustment")

# %%
axial_image_test_thresh = adaptive_thresh_images(axial_image_test_sharpened)
coronal_image_test_thresh = adaptive_thresh_images(coronal_image_test_sharpened)
sagittal_image_test_thresh = adaptive_thresh_images(sagittal_image_test_sharpened)

# %% [markdown]
# ## 1. Thư viện cần thiết

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os
import cv2
import random

# %%
# Đường lnk lấy dataset
axial_train_dataset = '/kaggle/input/brain-tumor-by-plane-object-detection/axial_t1wce_2_class/train/'
coronal_train_dataset = '/kaggle/input/brain-tumor-by-plane-object-detection/coronal_t1wce_2_class/train/'
sagittal_train_dataset = '/kaggle/input/brain-tumor-by-plane-object-detection/sagittal_t1wce_2_class/train/'
axial_test_dataset = '/kaggle/input/brain-tumor-by-plane-object-detection/axial_t1wce_2_class/test/'
coronal_test_dataset = '/kaggle/input/brain-tumor-by-plane-object-detection/coronal_t1wce_2_class/test/'
sagittal_test_dataset = '/kaggle/input/brain-tumor-by-plane-object-detection/sagittal_t1wce_2_class/test/'

# %% [markdown]
# ## 2. Làm sắc nét hình

# %%
def sharpen_images(image_list):
    sharpened_images = []
    
    # Kernel làm sắc nét
    sharpen_kernel = np.array([[0, -1, 0],
                               [-1, 5,-1],
                               [0, -1, 0]])
    
    for image in image_list:
        # Áp dụng kernel để làm sắc nét ảnh
        sharpened_image = cv2.filter2D(image, -1, sharpen_kernel)
        sharpened_images.append(sharpened_image)
    
    return sharpened_images

# %%
axial_image_train_sharpened = sharpen_images(axial_image_train_crop)
coronal_image_train_sharpened = sharpen_images(coronal_image_train_crop)
sagittal_image_train_sharpened = sharpen_images(sagittal_image_train_crop)

# %%
plot_images_with_bboxes(axial_image_train_sharpened, axial_labels_train,  "/kaggle/working/brain_tumor_object_detection/axial/train/labels", "Train Axial Sharpened")

# %%
plot_images_with_bboxes(coronal_image_train_sharpened, coronal_labels_train,  "/kaggle/working/brain_tumor_object_detection/coronal/train/labels", "Train Coronal Sharpened")

# %%
plot_images_with_bboxes(sagittal_image_train_sharpened, sagittal_labels_train,  "/kaggle/working/brain_tumor_object_detection/sagittal/train/labels", "Train Sagittal Sharpened")
